# %%
# Imports
import numpy as np 
import random
import networkx as nx
from networkx import karate_club_graph, to_numpy_matrix

# %%
G = nx.path_graph(4)
G.add_edge(5,6)
nx.draw(G, with_labels=True)
graphs = list(nx.connected_component_subgraphs(G))

# %%
graphs
# Out:
# [<networkx.classes.graph.Graph at 0x1445704a3c8>,
#  <networkx.classes.graph.Graph at 0x1445704a448>]

# %%
for i in graphs:
    nx.draw(i, with_labels=True)
    print("--------------")
# Out:
# --------------
# --------------
